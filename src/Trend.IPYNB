# %% [markdown]
# Implementation of Trend analysis
#
# --> https://doi.org/10.1371/journal.pone.0152802
# --> https://www.geeksforgeeks.org/machine-learning/how-to-perform-a-mann-kendall-trend-test-in-python/

# %%
! pip install pandas
! pip install matplotlib
! pip install scipy
! pip install seaborn
! pip install pymannkendall

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pymannkendall as mk

# %% [markdown]
# For Trend analysis like in Paper
#
# --> Mann Kendall Test

# %%
#create df & clean
df = pd.read_csv("Placeholder")
df.dropna()

df

# %%
# perform Mann-Kendall Trend Test
mk.original_test(df)
